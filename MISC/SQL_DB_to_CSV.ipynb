# %%
import psycopg2
import pandas as pd

conn = psycopg2.connect(
    host="localhost",
    port=5432,
    dbname="esgdb",
    user="esguser",
    password="esgpassword"
)

df = pd.read_sql("SELECT * FROM company_esg_scores", conn)
df1 = pd.read_sql("SELECT * FROM company_pdfs WHERE status='pending'", conn)
df.to_csv("database_as_csv/company_esg_scores.csv", index=False)
df1.to_csv("database_as_csv/pending_companies.csv", index=False)
conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[1], line 4
#       1 import psycopg2
#       2 import pandas as pd
# ----> 4 conn = psycopg2.connect(
#       5     host="localhost",
#       6     port=5432,
#       7     dbname="esgdb",
#       8     user="esguser",
#       9     password="esgpassword"
#      10 )
#      12 df = pd.read_sql("SELECT * FROM company_esg_scores", conn)
#      13 df1 = pd.read_sql("SELECT * FROM company_pdfs WHERE status='pending'", conn)
#
# File c:\Users\AS9Wa\.conda\envs\Main_Env\lib\site-packages\psycopg2\__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
# ...

# %%
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
